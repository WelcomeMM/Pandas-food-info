# %%
import pandas as pd

# %%
food_info = pd.read_csv("food_info.csv")
food_info
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
print(type(food_info))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
row_100 = food_info.loc[99]
row_100
# Out:
# NDB_No                                  1111
# Shrt_Desc          MILK SHAKES THICK VANILLA
# Water_(g)                              74.45
# Energ_Kcal                               112
# Protein_(g)                             3.86
# Lipid_Tot_(g)                           3.03
# Ash_(g)                                 0.91
# Carbohydrt_(g)                         17.75
# Fiber_TD_(g)                               0
# Sugar_Tot_(g)                          17.75
# Calcium_(mg)                             146
# Iron_(mg)                                0.1
# Magnesium_(mg)                            12
# Phosphorus_(mg)                          115
# Potassium_(mg)                           183
# Sodium_(mg)                               95
# Zinc_(mg)                               0.39
# Copper_(mg)                            0.051
# Manganese_(mg)                         0.014
# Selenium_(mcg)                           2.3
# Vit_C_(mg)                                 0
# ...

# %%
index_last_rows = (food_info.shape[0]) - 5

last_five_rows = food_info.loc[index_last_rows:]
last_five_rows
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
protein = food_info["Protein_(g)"]
cholesterol = food_info["Cholestrl_(mg)"]

# %%
protein
# Out:
# 0        0.85
# 1        0.85
# 2        0.28
# 3       21.40
# 4       23.24
#         ...
# 8613    18.50
# 8614    20.54
# 8615     0.00
# 8616    16.10
# 8617    19.80
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
cholesterol
# Out:
# 0       215.0
# 1       219.0
# 2       256.0
# 3        75.0
# 4        94.0
#         ...
# 8613     95.0
# 8614     41.0
# 8615      0.0
# 8616     50.0
# 8617     50.0
# Name: Cholestrl_(mg), Length: 8618, dtype: float64

# %%
food_info.columns.values
# Out:
# array(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)',
#        'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)',
#        'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)'], dtype=object)

# %%
selenium_thiamin = food_info[["Shrt_Desc", "Shrt_Desc", 'Thiamin_(mg)']]
selenium_thiamin
# Out:
#                        Shrt_Desc                   Shrt_Desc  Thiamin_(mg)
# 0               BUTTER WITH SALT            BUTTER WITH SALT         0.005
# 1       BUTTER WHIPPED WITH SALT    BUTTER WHIPPED WITH SALT         0.005
# 2           BUTTER OIL ANHYDROUS        BUTTER OIL ANHYDROUS         0.001
# 3                    CHEESE BLUE                 CHEESE BLUE         0.029
# 4                   CHEESE BRICK                CHEESE BRICK         0.014
# ...                          ...                         ...           ...
# 8613             MACKEREL SALTED             MACKEREL SALTED         0.020
# 8614  SCALLOP (BAY&SEA) CKD STMD  SCALLOP (BAY&SEA) CKD STMD         0.012
# 8615                  SYRUP CANE                  SYRUP CANE         0.130
# 8616                   SNAIL RAW                   SNAIL RAW         0.010
# 8617            TURTLE GREEN RAW            TURTLE GREEN RAW         0.120
#
# [8618 rows x 3 columns]

# %% [markdown]
# Select all columns with units gramm

# %%
columns_name = food_info.columns.values
columns_name
# Out:
# array(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)',
#        'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)',
#        'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)'], dtype=object)

# %%
columns_name = list(columns_name)
columns_name
# Out:
# ['NDB_No',
#  'Shrt_Desc',
#  'Water_(g)',
#  'Energ_Kcal',
#  'Protein_(g)',
#  'Lipid_Tot_(g)',
#  'Ash_(g)',
#  'Carbohydrt_(g)',
#  'Fiber_TD_(g)',
#  'Sugar_Tot_(g)',
#  'Calcium_(mg)',
#  'Iron_(mg)',
#  'Magnesium_(mg)',
#  'Phosphorus_(mg)',
#  'Potassium_(mg)',
#  'Sodium_(mg)',
#  'Zinc_(mg)',
#  'Copper_(mg)',
#  'Manganese_(mg)',
#  'Selenium_(mcg)',
#  'Vit_C_(mg)',
#  'Thiamin_(mg)',
#  'Riboflavin_(mg)',
#  'Niacin_(mg)',
#  'Vit_B6_(mg)',
#  'Vit_B12_(mcg)',
#  'Vit_A_IU',
#  'Vit_A_RAE',
#  'Vit_E_(mg)',
#  'Vit_D_mcg',
#  'Vit_D_IU',
#  'Vit_K_(mcg)',
#  'FA_Sat_(g)',
#  'FA_Mono_(g)',
#  'FA_Poly_(g)',
#  'Cholestrl_(mg)']

# %%
gram_columns = []

for i in columns_name:
    if i.endswith("(g)"):
        gram_columns.append(i)

gram_columns
# Out:
# ['Water_(g)',
#  'Protein_(g)',
#  'Lipid_Tot_(g)',
#  'Ash_(g)',
#  'Carbohydrt_(g)',
#  'Fiber_TD_(g)',
#  'Sugar_Tot_(g)',
#  'FA_Sat_(g)',
#  'FA_Mono_(g)',
#  'FA_Poly_(g)']

# %%
df_gram = food_info[gram_columns]
df_gram
# Out:
#       Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0         15.87         0.85          81.11     2.11            0.06
# 1         15.87         0.85          81.11     2.11            0.06
# 2          0.24         0.28          99.48     0.00            0.00
# 3         42.41        21.40          28.74     5.11            2.34
# 4         41.11        23.24          29.68     3.18            2.79
# ...         ...          ...            ...      ...             ...
# 8613      43.00        18.50          25.10    13.40            0.00
# 8614      70.25        20.54           0.84     2.97            5.41
# 8615      26.00         0.00           0.00     0.86           73.14
# 8616      79.20        16.10           1.40     1.30            2.00
# 8617      78.50        19.80           0.50     1.20            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# ...

# %%
sodium_gram = food_info["Sodium_(mg)"] / 1000
sodium_gram
# Out:
# 0       0.643
# 1       0.659
# 2       0.002
# 3       1.146
# 4       0.560
#         ...
# 8613    4.450
# 8614    0.667
# 8615    0.058
# 8616    0.070
# 8617    0.068
# Name: Sodium_(mg), Length: 8618, dtype: float64

# %%
sugar_milligram = food_info["Sugar_Tot_(g)"] * 1000
sugar_milligram
# Out:
# 0          60.0
# 1          60.0
# 2           0.0
# 3         500.0
# 4         510.0
#          ...
# 8613        0.0
# 8614        0.0
# 8615    73200.0
# 8616        0.0
# 8617        0.0
# Name: Sugar_Tot_(g), Length: 8618, dtype: float64

# %%
food_info.columns.values
# Out:
# array(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)',
#        'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)',
#        'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)'], dtype=object)

# %%
gram_of_protein_per_gram_of_water = food_info["Protein_(g)"] / food_info["Water_(g)"]
milligrams_of_calcium_and_iron = food_info["Calcium_(mg)"] + food_info["Iron_(mg)"]

# %%
gram_of_protein_per_gram_of_water.head()
# Out:
# 0    0.053560
# 1    0.053560
# 2    1.166667
# 3    0.504598
# 4    0.565313
# dtype: float64

# %%
milligrams_of_calcium_and_iron.head()
# Out:
# 0     24.02
# 1     24.16
# 2      4.00
# 3    528.31
# 4    674.43
# dtype: float64

# %%
protein = food_info["Protein_(g)"] * 2
fat = food_info["Lipid_Tot_(g)"] * (- 0.75)

# %%
rating = protein + fat
rating
# Out:
# 0      -59.1325
# 1      -59.1325
# 2      -74.0500
# 3       21.2450
# 4       24.2200
#          ...
# 8613    18.1750
# 8614    40.4500
# 8615     0.0000
# 8616    31.1500
# 8617    39.2250
# Length: 8618, dtype: float64

# %%
normalized_protein = food_info["Protein_(g)"] / (food_info["Protein_(g)"].max())
normalized_lipid = food_info["Lipid_Tot_(g)"] / (food_info["Lipid_Tot_(g)"].max())

# %%
normalized_protein
# Out:
# 0       0.009624
# 1       0.009624
# 2       0.003170
# 3       0.242301
# 4       0.263134
#           ...
# 8613    0.209466
# 8614    0.232563
# 8615    0.000000
# 8616    0.182292
# 8617    0.224185
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
normalized_lipid
# Out:
# 0       0.8111
# 1       0.8111
# 2       0.9948
# 3       0.2874
# 4       0.2968
#          ...
# 8613    0.2510
# 8614    0.0084
# 8615    0.0000
# 8616    0.0140
# 8617    0.0050
# Name: Lipid_Tot_(g), Length: 8618, dtype: float64

# %%
food_info = pd.read_csv("food_info.csv")

# %%
food_info["Normalized_protein"] = normalized_protein
food_info["Normalized_fat"] = normalized_lipid

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
# ...

# %%
food_info["Norm_nutr_index"] = (food_info["Normalized_protein"] * 2)   + ((-0.75) * food_info["Normalized_fat"])
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
# ...

# %%
food_info.sort_values("Norm_nutr_index", inplace=True, ascending=False)
food_info.head()
# Out:
#       NDB_No                                         Shrt_Desc  Water_(g)  \
# 4991   16423          SOY PROT ISOLATE K TYPE CRUDE PROT BASIS       4.98
# 6155   19177                          GELATINS DRY PDR UNSWTND      13.00
# 216     1258            EGG WHITE DRIED STABILIZED GLUCOSE RED       6.53
# 124     1136        EGG WHITE DRIED PDR STABILIZED GLUCOSE RED       8.54
# 8152   35055  SEAL BEARDED (OOGRUK) MEAT DRIED (ALASKA NATIVE)      11.60
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 4991         321        88.32           0.53     3.58            2.59
# 6155         335        85.60           0.10     1.30            0.00
# 216          362        84.63           0.48     3.63            4.72
# 124          376        82.40           0.04     4.55            4.47
# 8152         351        82.60           2.30     3.50            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  ...  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...
